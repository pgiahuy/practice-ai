# %%
import numpy as np

a = np.array([1, 2])
b = np.array([3, 4])

c = np.concatenate((a, b))
print(c)
# Out:
# [1 2 3 4]
# [3 4]

# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ----------- ---------------------------- 3.7/12.3 MB 24.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.3 MB 30.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 29.7 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
